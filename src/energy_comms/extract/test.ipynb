# %%
import pandas as pd

# %%
# %load_ext autoreload
# %autoreload 3

# %%
import logging
import sys

# %%
import qcew_2010_2021
from qcew_2010_2021 import *

# %%
yrs = ['2010','2011','2012','2013','2014','2015','2016','2017','2018','2019','2020','2021']

# %%
download_all(yrs)

# %%
for yr in yrs:
    k = make_year_df_2(yr)

# %%
k
# Out:
#         area_fips  own_code industry_code  agglvl_code  size_code  year qtr  \
# 0            1001         0            10           70          0  2021   A
# 1            1001         1            10           71          0  2021   A
# 2            1001         1           102           72          0  2021   A
# 3            1001         1          1021           73          0  2021   A
# 4            1001         1          1028           73          0  2021   A
# ...           ...       ...           ...          ...        ...   ...  ..
# 3243253     C4974         5         99999           47          0  2021   A
# 3243254     C4974         5        999999           48          0  2021   A
# 3243255     CS122         0            10           30          0  2021   A
# 3243256     CS350         0            10           30          0  2021   A
# 3243257     USMSA         0            10           91          0  2021   A
#
#         disclosure_code                                         area_title  \
# 0                   NaN                            Autauga County, Alabama
# 1                   NaN                            Autauga County, Alabama
# 2                   NaN                            Autauga County, Alabama
# 3                   NaN                            Autauga County, Alabama
# 4                   NaN                            Autauga County, Alabama
# ...                 ...                                                ...
# 3243253             NaN                                       Yuma, AZ MSA
# 3243254             NaN                                       Yuma, AZ MSA
# 3243255             NaN  Atlanta--Athens-Clarke County--Sandy Springs, ...
# 3243256             NaN  Louisville-Jefferson County--Elizabethtown--Ma...
# 3243257             NaN     U.S. Metropolitan Statistical Areas (combined)
#
#                   own_title  ... oty_total_annual_wages_chg  \
# 0             Total Covered  ...                   23824026
# 1        Federal Government  ...                    -105325
# 2        Federal Government  ...                    -105325
# 3        Federal Government  ...                     -26210
# 4        Federal Government  ...                     -79115
# ...                     ...  ...                        ...
# 3243253             Private  ...                     744376
# 3243254             Private  ...                     744376
# 3243255       Total Covered  ...                16770355216
# 3243256       Total Covered  ...                 2882022844
# 3243257       Total Covered  ...               679629425568
#
#         oty_total_annual_wages_pct_chg oty_taxable_annual_wages_chg  \
# 0                                  5.1                      5062649
# 1                                 -2.1                            0
# 2                                 -2.1                            0
# 3                                 -0.6                            0
# 4                                 -8.8                            0
# ...                                ...                          ...
# 3243253                          117.6                       295820
# 3243254                          117.6                       295820
# 3243255                            9.2                   2465798353
# 3243256                            7.6                    549366318
# 3243257                            8.6                 109504935823
#
#          oty_taxable_annual_wages_pct_chg  oty_annual_contributions_chg  \
# 0                                     6.5                        449848
# 1                                     0.0                             0
# 2                                     0.0                             0
# 3                                     0.0                             0
# 4                                     0.0                             0
# ...                                   ...                           ...
# 3243253                              80.7                          5127
# 3243254                              80.7                          5127
# 3243255                               8.4                      37667720
# 3243256                               7.6                       6658646
# 3243257                               7.5                    4619091378
#
#          oty_annual_contributions_pct_chg  oty_annual_avg_wkly_wage_chg  \
# 0                                    46.7                            16
# 1                                     0.0                           119
# 2                                     0.0                           119
# 3                                     0.0                            67
# 4                                     0.0                           365
# ...                                   ...                           ...
# 3243253                              56.4                            20
# 3243254                              56.4                            20
# 3243255                              10.9                            67
# 3243256                               5.4                            46
# 3243257                              18.2                            67
#
#          oty_annual_avg_wkly_wage_pct_chg  oty_avg_annual_pay_chg  \
# 0                                     1.9                     868
# 1                                    10.9                    6194
# 2                                    10.9                    6194
# 3                                     6.0                    3477
# 4                                    37.8                   18973
# ...                                   ...                     ...
# 3243253                               3.8                    1027
# 3243254                               3.8                    1027
# 3243255                               5.4                    3483
# 3243256                               4.3                    2359
# 3243257                               5.3                    3503
#
#          oty_avg_annual_pay_pct_chg
# 0                               2.0
# 1                              10.9
# 2                              10.9
# 3                               6.0
# 4                              37.8
# ...                             ...
# 3243253                         3.8
# 3243254                         3.8
# 3243255                         5.4
# 3243256                         4.3
# 3243257                         5.3
#
# [3243258 rows x 43 columns]
