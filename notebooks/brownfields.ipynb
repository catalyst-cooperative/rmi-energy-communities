# %%
# %load_ext autoreload
# %autoreload 3

# %%
import logging
import sys
import energy_comms

# %%
logger = logging.getLogger()
logger.setLevel(logging.INFO)
handler = logging.StreamHandler(stream=sys.stdout)
formatter = logging.Formatter()
handler.setFormatter(formatter)
logger.handlers = [handler]

# %%
from energy_comms.extract.epa import extract as brownfields_extract

from energy_comms.transform.epa import transform as brownfields_transform

# %%
brownfields = brownfields_transform(brownfields_extract())

# %%
brownfields
# Out:
#                                        area_name   latitude   longitude state  \
# 0                     Kerramerican Mine (Former)  44.390000  -68.620000    ME
# 1                    Vermont Asbestos Group Mine  44.750000  -72.516667    VT
# 2                                    Daley Court  41.778857  -72.614299    CT
# 3                                Interstate Lane  41.531557  -72.993027    CT
# 4         Pope Park Zion Llc 41-43 School Street  41.748130  -72.684830    CT
# ...                                          ...        ...         ...   ...
# 190971  Vancouver Water Station #1 Contamination  45.638471 -122.645417    WA
# 190972  Vancouver Water Station #4 Contamination  45.619500 -122.622472    WA
# 190973              Western Processing Co., Inc.  47.425000 -122.241700    WA
# 190974                  Wyckoff Co./Eagle Harbor  47.621669 -122.516700    WA
# 190975                        Yakima Plating Co.  46.572300 -120.508900    WA
#
#        qualifying_area    criteria fips_county
# 0                 site  brownfield       23009
# 1                 site  brownfield       50019
# 2                 site  brownfield       09003
# 3                 site  brownfield       09009
# 4                 site  brownfield       09003
# ...                ...         ...         ...
# 190971            site  brownfield       53011
# 190972            site  brownfield       53011
# 190973            site  brownfield       53033
# 190974            site  brownfield       53033
# 190975            site  brownfield       53077
#
# [190976 rows x 7 columns]
